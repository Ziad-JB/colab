# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziad-JB/colab/blob/main/Copy3_of_Torrent_To_Google_Drive_Downloader_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Torrent To Google Drive Downloader v2

# %% [markdown]
# ### Mount Google Drive
# To stream files we need to mount Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Dependency
# https://www.libtorrent.org/

# %%
# !pip install qiskit ipywidgets
# !python -m pip install --upgrade pip setuptools wheel
# !python -m pip install lbry-libtorrent
# !pip install folium==0.2.1
# !apt install python3-libtorrent
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libtorrent-rasterbar9
# Suggested packages:
#   libtorrent-rasterbar-dbg
# The following NEW packages will be installed:
#   libtorrent-rasterbar9 python3-libtorrent
# 0 upgraded, 2 newly installed, 0 to remove and 30 not upgraded.
# Need to get 1,569 kB of archives.
# After this operation, 5,718 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtorrent-rasterbar9 amd64 1.1.5-1build1 [1,258 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-libtorrent amd64 1.1.5-1build1 [310 kB]
# Fetched 1,401 kB in 2s (626 kB/s)
# Selecting previously unselected package libtorrent-rasterbar9.
# (Reading database ... 160980 files and directories currently installed.)
# Preparing to unpack .../libtorrent-rasterbar9_1.1.5-1build1_amd64.deb ...
# ...

# %% [markdown]
# ### Code to download torrent
# Variable **link** stores the link string.

# %%
import libtorrent as lt
import time
import datetime

ses = lt.session()
ses.listen_on(6881, 6891)
params = {
    'save_path': '/content/drive/My Drive/Torrent/',
    'storage_mode': lt.storage_mode_t(2)
    }
link = "magnet:?xt=urn:btih:813D888BC387498DFFE857920D0E16881BF72283&tr=http%3A%2F%2Fbt3.t-ru.org%2Fann%3Fmagnet&dn=%5BBusy%20Works%20Beats%5D%20The%20Mixing%20Academy%20Complete%20(Bundle)%20%5B2018%2C%20ENG%5D" # PASTE TORRENT/MAGNET LINK HERE
print(link)

handle = lt.add_magnet_uri(ses, link, params)
ses.start_dht()

begin = time.time()
print(datetime.datetime.now())

print ('Downloading Metadata...')
while (not handle.has_metadata()):
    time.sleep(1)
print ('Got Metadata, Starting Torrent Download...')

print("Starting", handle.name())

while (handle.status().state != lt.torrent_status.seeding):
    s = handle.status()
    state_str = ['queued', 'checking', 'downloading metadata', \
            'downloading', 'finished', 'seeding', 'allocating']
    print ('%.2f%% complete (down: %.1f kb/s up: %.1f kB/s peers: %d) %s ' % \
            (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
            s.num_peers, state_str[s.state]))
    time.sleep(5)

end = time.time()
print(handle.name(), "COMPLETE")

print("Elapsed Time: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")

print(datetime.datetime.now())
# Out:
# magnet:?xt=urn:btih:813D888BC387498DFFE857920D0E16881BF72283&tr=http%3A%2F%2Fbt3.t-ru.org%2Fann%3Fmagnet&dn=%5BBusy%20Works%20Beats%5D%20The%20Mixing%20Academy%20Complete%20(Bundle)%20%5B2018%2C%20ENG%5D
# 2021-03-25 21:07:12.601490
# ...
# Got Metadata, Starting Torrent Download...
# Starting Busy Works Beats - The Mixing Academy Complete Bundle
# 0.00% complete (down: 55.1 kb/s up: 2.0 kB/s peers: 2) checking
# 0.43% complete (down: 18.3 kb/s up: 0.9 kB/s peers: 2) checking
# 0.73% complete (down: 6.2 kb/s up: 0.6 kB/s peers: 2) checking
# 1.13% complete (down: 2.4 kb/s up: 0.6 kB/s peers: 2) checking
# 1.43% complete (down: 1.0 kb/s up: 0.5 kB/s peers: 2) checking
# 1.76% complete (down: 0.6 kb/s up: 0.5 kB/s peers: 2) checking
# 2.08% complete (down: 0.5 kb/s up: 0.6 kB/s peers: 2) checking
# 2.39% complete (down: 0.5 kb/s up: 0.6 kB/s peers: 2) checking
# 2.58% complete (down: 0.4 kb/s up: 0.4 kB/s peers: 2) checking
# 2.84% complete (down: 0.3 kb/s up: 0.4 kB/s peers: 2) checking
# ...
